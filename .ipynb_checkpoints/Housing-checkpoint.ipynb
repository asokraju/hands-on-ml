# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import os
import urllib

# %%
download_url = 'http://lib.stat.cmu.edu/datasets/houses.zip'
data_path = './datasets/housing'
def fetch_data(source_url = download_url, local_path = data_path):
    if not os.path.isdir(local_path):
        os.makedirs(local_path)
    urllib.request.urlretrieve(download_url, local_path)
    files = os.listdir(local_path)
    print(files)

# %%
fetch_data(source_url = download_url, local_path = data_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-15-c9d285f38158> in <module>
# ----> 1 fetch_data(source_url = download_url, local_path = data_path)
#
# <ipython-input-14-6b848f9e3598> in fetch_data(source_url, local_path)
#       4     if not os.path.isdir(local_path):
#       5         os.makedirs(local_path)
# ----> 6     urllib.request.urlretrieve(download_url, local_path)
#       7     files = os.listdir(local_path)
#       8     print(files)
#
# ~\anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# PermissionError: [Errno 13] Permission denied: './datasets/housing'

# %%
col_names = ['longitude','latitude','housingmedianage','total_rooms','total_bedrooms','population','households','median_income','medianhousevalue']
#'ocean_proximity'
df = pd.read_csv(download_url, compression='zip', names = col_names, skiprows=27, header=None, sep = '\s+')
df.head()
# Out:
#    longitude  latitude  housingmedianage  total_rooms  total_bedrooms  \
# 0   452600.0    8.3252              41.0        880.0           129.0
# 1   358500.0    8.3014              21.0       7099.0          1106.0
# 2   352100.0    7.2574              52.0       1467.0           190.0
# 3   341300.0    5.6431              52.0       1274.0           235.0
# 4   342200.0    3.8462              52.0       1627.0           280.0
#
#    population  households  median_income  medianhousevalue
# 0       322.0       126.0          37.88           -122.23
# 1      2401.0      1138.0          37.86           -122.22
# 2       496.0       177.0          37.85           -122.24
# 3       558.0       219.0          37.85           -122.25
# 4       565.0       259.0          37.85           -122.25

# %%
df.describe()
# Out:
#            longitude      latitude  housingmedianage   total_rooms  \
# count   20640.000000  20640.000000      20640.000000  20640.000000
# mean   206855.816909      3.870671         28.639486   2635.763081
# std    115395.615874      1.899822         12.585558   2181.615252
# min     14999.000000      0.499900          1.000000      2.000000
# 25%    119600.000000      2.563400         18.000000   1447.750000
# 50%    179700.000000      3.534800         29.000000   2127.000000
# 75%    264725.000000      4.743250         37.000000   3148.000000
# max    500001.000000     15.000100         52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.898014   1425.476744    499.539680      35.631861
# std        421.247906   1132.462122    382.329753       2.135952
# min          1.000000      3.000000      1.000000      32.540000
# 25%        295.000000    787.000000    280.000000      33.930000
# 50%        435.000000   1166.000000    409.000000      34.260000
# 75%        647.000000   1725.000000    605.000000      37.710000
# max       6445.000000  35682.000000   6082.000000      41.950000
#
#        medianhousevalue
# count      20640.000000
# mean        -119.569704
# std            2.003532
# min         -124.350000
# 25%         -121.800000
# 50%         -118.490000
# 75%         -118.010000
# max         -114.310000
